# %%
import requests

# %%
standing_url = "https://fbref.com/en/comps/9/Premier-League-Stats"

# %%
data = requests.get(standing_url)

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(data.text)
standing_table = soup.select('table.stats_table')[0]
links = standing_table.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if '/squads/' in l]
links
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 soup = BeautifulSoup(data.text)
# ----> 2 standing_table = soup.select('table.stats_table')[0]
#       3 links = standing_table.find_all('a')
#       4 links = [l.get("href") for l in links]
#
# IndexError: list index out of range

# %%
team_urls = [f"https://fbref.com{l}" for l in links]
team_urls
# Out:
# ['https://fbref.com/en/squads/822bd0ba/Liverpool-Stats',
#  'https://fbref.com/en/squads/b8fd03ef/Manchester-City-Stats',
#  'https://fbref.com/en/squads/18bb7c10/Arsenal-Stats',
#  'https://fbref.com/en/squads/8602292d/Aston-Villa-Stats',
#  'https://fbref.com/en/squads/361ca564/Tottenham-Hotspur-Stats',
#  'https://fbref.com/en/squads/19538871/Manchester-United-Stats',
#  'https://fbref.com/en/squads/7c21e445/West-Ham-United-Stats',
#  'https://fbref.com/en/squads/d07537b9/Brighton-and-Hove-Albion-Stats',
#  'https://fbref.com/en/squads/b2b47a98/Newcastle-United-Stats',
#  'https://fbref.com/en/squads/8cec06e1/Wolverhampton-Wanderers-Stats',
#  'https://fbref.com/en/squads/cff3d9bb/Chelsea-Stats',
#  'https://fbref.com/en/squads/4ba7cbea/Bournemouth-Stats',
#  'https://fbref.com/en/squads/fd962109/Fulham-Stats',
#  'https://fbref.com/en/squads/47c64c55/Crystal-Palace-Stats',
#  'https://fbref.com/en/squads/cd051869/Brentford-Stats',
#  'https://fbref.com/en/squads/e4a775cb/Nottingham-Forest-Stats',
#  'https://fbref.com/en/squads/e297cd13/Luton-Town-Stats',
#  'https://fbref.com/en/squads/d3fd31cc/Everton-Stats',
#  'https://fbref.com/en/squads/943e8050/Burnley-Stats',
#  'https://fbref.com/en/squads/1df6b87e/Sheffield-United-Stats']

# %%
data = requests.get(team_urls[0])
data
# Out:
# <Response [200]>

# %%
import pandas as pd
matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
matches.head(3)
# Out:
#          Date   Time            Comp        Round  Day Venue Result   GF   GA  \
# 0  2023-08-13  16:30  Premier League  Matchweek 1  Sun  Away      D  1.0  1.0
# 1  2023-08-19  15:00  Premier League  Matchweek 2  Sat  Home      W  3.0  1.0
# 2  2023-08-27  16:30  Premier League  Matchweek 3  Sun  Away      W  2.0  1.0
#
#         Opponent   xG  xGA  Poss  Attendance          Captain Formation  \
# 0        Chelsea  1.3  1.4  35.0     40096.0  Virgil van Dijk     4-3-3
# 1    Bournemouth  3.0  1.3  64.0     53145.0  Virgil van Dijk     4-3-3
# 2  Newcastle Utd  0.9  2.0  41.0     52214.0  Virgil van Dijk     4-3-3
#
#           Referee  Match Report Notes
# 0  Anthony Taylor  Match Report   NaN
# 1  Thomas Bramall  Match Report   NaN
# 2     John Brooks  Match Report   NaN

# %%
soup = BeautifulSoup(data.text)
links = soup.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if l and 'all_comps/shooting/' in l]
links
# Out:
# ['/en/squads/822bd0ba/2023-2024/matchlogs/all_comps/shooting/Liverpool-Match-Logs-All-Competitions',
#  '/en/squads/822bd0ba/2023-2024/matchlogs/all_comps/shooting/Liverpool-Match-Logs-All-Competitions',
#  '/en/squads/822bd0ba/2023-2024/matchlogs/all_comps/shooting/Liverpool-Match-Logs-All-Competitions',
#  '/en/squads/822bd0ba/2023-2024/matchlogs/all_comps/shooting/Liverpool-Match-Logs-All-Competitions']

# %%
data = requests.get(f"https://fbref.com{links[0]}")
data
# Out:
# <Response [200]>

# %%
shooting = pd.read_html(data.text, match="Shooting")[0]
shooting.head(3)
# Out:
#   For Liverpool                                                             \
#            Date   Time            Comp        Round  Day Venue Result   GF
# 0    2023-08-13  16:30  Premier League  Matchweek 1  Sun  Away      D  1.0
# 1    2023-08-19  15:00  Premier League  Matchweek 2  Sat  Home      W  3.0
# 2    2023-08-27  16:30  Premier League  Matchweek 3  Sun  Away      W  2.0
#
#                        ... Standard               Expected                    \
#     GA       Opponent  ...     Dist   FK PK PKatt       xG npxG npxG/Sh G-xG
# 0  1.0        Chelsea  ...     17.8  0.0  0     0      1.3  1.3    0.10 -0.3
# 1  1.0    Bournemouth  ...     16.8  1.0  0     1      3.0  2.1    0.09  0.0
# 2  1.0  Newcastle Utd  ...     17.2  1.0  0     0      0.9  0.9    0.10  1.1
#
#           Unnamed: 25_level_0
#   np:G-xG        Match Report
# 0    -0.3        Match Report
# 1     0.9        Match Report
# 2     1.1        Match Report
#
# [3 rows x 26 columns]

# %%
shooting.columns = shooting.columns.droplevel()
shooting.columns
# Out:
# Index(['Date', 'Time', 'Comp', 'Round', 'Day', 'Venue', 'Result', 'GF', 'GA',
#        'Opponent', 'Gls', 'Sh', 'SoT', 'SoT%', 'G/Sh', 'G/SoT', 'Dist', 'FK',
#        'PK', 'PKatt', 'xG', 'npxG', 'npxG/Sh', 'G-xG', 'np:G-xG',
#        'Match Report'],
#       dtype='object')

# %%
team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")
team_data
# Out:
#           Date   Time            Comp                Round  Day Venue Result  \
# 0   2023-08-13  16:30  Premier League          Matchweek 1  Sun  Away      D
# 1   2023-08-19  15:00  Premier League          Matchweek 2  Sat  Home      W
# 2   2023-08-27  16:30  Premier League          Matchweek 3  Sun  Away      W
# 3   2023-09-03  14:00  Premier League          Matchweek 4  Sun  Home      W
# 4   2023-09-16  12:30  Premier League          Matchweek 5  Sat  Away      W
# 5   2023-09-21  18:45       Europa Lg          Group stage  Thu  Away      W
# 6   2023-09-24  14:00  Premier League          Matchweek 6  Sun  Home      W
# 7   2023-09-27  19:45         EFL Cup          Third round  Wed  Home      W
# 8   2023-09-30  17:30  Premier League          Matchweek 7  Sat  Away      L
# 9   2023-10-05  20:00       Europa Lg          Group stage  Thu  Home      W
# 10  2023-10-08  14:00  Premier League          Matchweek 8  Sun  Away      D
# 11  2023-10-21  12:30  Premier League          Matchweek 9  Sat  Home      W
# 12  2023-10-26  20:00       Europa Lg          Group stage  Thu  Home      W
# 13  2023-10-29  14:00  Premier League         Matchweek 10  Sun  Home      W
# 14  2023-11-01  19:45         EFL Cup         Fourth round  Wed  Away      W
# 15  2023-11-05  16:30  Premier League         Matchweek 11  Sun  Away      D
# 16  2023-11-09  18:45       Europa Lg          Group stage  Thu  Away      L
# 17  2023-11-12  14:00  Premier League         Matchweek 12  Sun  Home      W
# 18  2023-11-25  12:30  Premier League         Matchweek 13  Sat  Away      D
# 19  2023-11-30  20:00       Europa Lg          Group stage  Thu  Home      W
# 20  2023-12-03  14:00  Premier League         Matchweek 14  Sun  Home      W
# 21  2023-12-06  19:30  Premier League         Matchweek 15  Wed  Away      W
# 22  2023-12-09  12:30  Premier League         Matchweek 16  Sat  Away      W
# 23  2023-12-14  18:45       Europa Lg          Group stage  Thu  Away      L
# 24  2023-12-17  16:30  Premier League         Matchweek 17  Sun  Home      D
# 25  2023-12-20  20:00         EFL Cup       Quarter-finals  Wed  Home      W
# 26  2023-12-23  17:30  Premier League         Matchweek 18  Sat  Home      D
# 27  2023-12-26  17:30  Premier League         Matchweek 19  Tue  Away      W
# 28  2024-01-01  20:00  Premier League         Matchweek 20  Mon  Home      W
# 29  2024-01-07  16:30          FA Cup   Third round proper  Sun  Away      W
# 30  2024-01-10  20:00         EFL Cup          Semi-finals  Wed  Home      W
# 31  2024-01-21  16:30  Premier League         Matchweek 21  Sun  Away      W
# 32  2024-01-24  20:00         EFL Cup          Semi-finals  Wed  Away      D
# 33  2024-01-28  14:30          FA Cup  Fourth round proper  Sun  Home      W
# 34  2024-01-31  20:15  Premier League         Matchweek 22  Wed  Home      W
# 35  2024-02-04  16:30  Premier League         Matchweek 23  Sun  Away      L
#
#      GF   GA         Opponent  ...  Formation         Referee  Match Report  \
# 0   1.0  1.0          Chelsea  ...      4-3-3  Anthony Taylor  Match Report
# 1   3.0  1.0      Bournemouth  ...      4-3-3  Thomas Bramall  Match Report
# 2   2.0  1.0    Newcastle Utd  ...      4-3-3     John Brooks  Match Report
# 3   3.0  0.0      Aston Villa  ...      4-3-3    Simon Hooper  Match Report
# 4   3.0  1.0           Wolves  ...      4-3-3  Michael Oliver  Match Report
# 5   3.0  1.0          at LASK  ...      4-3-3  Marco Di Bello  Match Report
# 6   3.0  1.0         West Ham  ...      4-3-3  Chris Kavanagh  Match Report
# 7   3.0  1.0   Leicester City  ...      4-3-3    Tim Robinson  Match Report
# 8   1.0  2.0        Tottenham  ...      4-3-3    Simon Hooper  Match Report
# 9   2.0  0.0      be Union SG  ...      4-3-3    Morten Krogh  Match Report
# 10  2.0  2.0         Brighton  ...      4-3-3  Anthony Taylor  Match Report
# 11  2.0  0.0          Everton  ...      4-3-3    Craig Pawson  Match Report
# 12  5.0  1.0      fr Toulouse  ...      4-3-3  Rade Obrenović  Match Report
# 13  3.0  0.0  Nott'ham Forest  ...      4-3-3  Chris Kavanagh  Match Report
# 14  2.0  1.0      Bournemouth  ...      4-3-3     John Brooks  Match Report
# 15  1.0  1.0       Luton Town  ...      4-3-3     Andy Madley  Match Report
# 16  2.0  3.0      fr Toulouse  ...      4-3-3  Georgi Kabakov  Match Report
# 17  3.0  0.0        Brentford  ...      4-3-3    Paul Tierney  Match Report
# 18  1.0  1.0  Manchester City  ...      4-3-3  Chris Kavanagh  Match Report
# 19  4.0  0.0          at LASK  ...      4-3-3    Urs Schnyder  Match Report
# 20  4.0  3.0           Fulham  ...      4-3-3  Stuart Attwell  Match Report
# 21  2.0  0.0    Sheffield Utd  ...      4-3-3    Simon Hooper  Match Report
# 22  2.0  1.0   Crystal Palace  ...      4-3-3     Andy Madley  Match Report
# 23  1.0  2.0      be Union SG  ...      4-3-3  Orel Grinfeeld  Match Report
# 24  0.0  0.0   Manchester Utd  ...      4-3-3  Michael Oliver  Match Report
# 25  5.0  1.0         West Ham  ...      4-3-3    Tim Robinson  Match Report
# 26  1.0  1.0          Arsenal  ...      4-3-3  Chris Kavanagh  Match Report
# 27  2.0  0.0          Burnley  ...      4-3-3    Paul Tierney  Match Report
# 28  4.0  2.0    Newcastle Utd  ...      4-3-3  Anthony Taylor  Match Report
# 29  2.0  0.0          Arsenal  ...      4-3-3     John Brooks  Match Report
# 30  2.0  1.0           Fulham  ...      4-3-3     David Coote  Match Report
# 31  4.0  0.0      Bournemouth  ...      4-3-3     Andy Madley  Match Report
# 32  1.0  1.0           Fulham  ...      4-3-3    Simon Hooper  Match Report
# 33  5.0  2.0     Norwich City  ...      4-3-3  Samuel Barrott  Match Report
# 34  4.0  1.0          Chelsea  ...      4-3-3    Paul Tierney  Match Report
# 35  1.0  3.0          Arsenal  ...      4-3-3  Anthony Taylor  Match Report
#
#                         Notes  Sh SoT  Dist   FK PK  PKatt
# 0                         NaN  13   1  17.8  0.0  0      0
# 1                         NaN  25   9  16.8  1.0  0      1
# 2                         NaN   9   4  17.2  1.0  0      0
# 3                         NaN  17   4  14.7  0.0  0      0
# 4                         NaN  16   5  15.8  0.0  0      0
# 5                         NaN  13   4  16.1  0.0  1      1
# 6                         NaN  21   6  19.3  2.0  1      1
# 7                         NaN  29  10   NaN  NaN  0      0
# 8                         NaN  12   4  14.9  0.0  0      0
# 9                         NaN  19   9  17.2  0.0  0      0
# 10                        NaN  13   3  18.8  0.0  1      1
# 11                        NaN  25   5  22.4  1.0  1      1
# 12                        NaN  20   9  17.6  0.0  0      0
# 13                        NaN  21   8  19.5  2.0  0      0
# 14                        NaN  18   7   NaN  NaN  0      0
# 15                        NaN  24   6  17.5  0.0  0      0
# 16                        NaN  19   4  20.8  0.0  0      0
# 17                        NaN  17  10  19.0  0.0  0      0
# 18                        NaN   8   3  15.9  0.0  0      0
# 19                        NaN  23   8  18.3  1.0  1      1
# 20                        NaN  26  12  18.9  1.0  0      0
# 21                        NaN  15   8  16.4  0.0  0      0
# 22                        NaN  14   2  17.4  0.0  0      0
# 23                        NaN   4   3  16.9  0.0  0      0
# 24                        NaN  34   8  17.7  0.0  0      0
# 25                        NaN  29  11   NaN  NaN  0      0
# 26                        NaN  13   3  20.1  1.0  0      0
# 27                        NaN  19  10  17.4  0.0  0      0
# 28                        NaN  32  12  16.2  0.0  1      2
# 29                        NaN  12   3   NaN  NaN  0      0
# 30                 Leg 1 of 2  21   7   NaN  NaN  0      0
# 31                        NaN  14   7  19.2  0.0  0      0
# 32  Leg 2 of 2; Liverpool won  14   5   NaN  NaN  0      0
# 33                        NaN  29  10   NaN  NaN  0      0
# 34                        NaN  27  13  19.9  2.0  0      1
# 35                        NaN  10   1  19.7  0.0  0      0
#
# [36 rows x 25 columns]

# %%
years = list(range(2022, 2020, -1))
all_matches = []

# %%
standings_url = "https://fbref.com/en/comps/9/Premier-League-Stats"

# %%
import time
for year in years:
    data = requests.get(standings_url)
    soup = BeautifulSoup(data.text)
    standings_table = soup.select('table.stats_table')[0]

    links = [l.get("href") for l in standings_table.find_all('a')]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
    
    previous_season = soup.select("a.prev")[0].get("href")
    standings_url = f"https://fbref.com{previous_season}"
    
    for team_url in team_urls:
        team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")
        data = requests.get(team_url)
        matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
        soup = BeautifulSoup(data.text)
        links = [l.get("href") for l in soup.find_all('a')]
        links = [l for l in links if l and 'all_comps/shooting/' in l]
        data = requests.get(f"https://fbref.com{links[0]}")
        shooting = pd.read_html(data.text, match="Shooting")[0]
        shooting.columns = shooting.columns.droplevel()
        try:
            team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")
        except ValueError:
            continue
        team_data = team_data[team_data["Comp"] == "Premier League"]
        
        team_data["Season"] = year
        team_data["Team"] = team_name
        all_matches.append(team_data)
        time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 17
#      15 team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")
#      16 data = requests.get(team_url)
# ---> 17 matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
#      18 soup = BeautifulSoup(data.text)
#      19 links = [l.get("href") for l in soup.find_all('a')]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py:1212, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend)
#    <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=1207'>1208</a> check_dtype_backend(dtype_backend)
#    <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=1209'>1210</a> io = stringify_path(io)
# -> <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=1211'>1212</a> return _parse(
#    <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=1212'>1213</a>     flavor=flavor,
#    <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=1213'>1214</a>     io=io,
#    <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=1214'>1215</a>     match=match,
#    <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=1215'>1216</a>     header=header,
#    <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=1216'>1217</a>     index_col=index_col,
#    <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=1217'>1218</a>     skiprows=skiprows,
#    <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=1218'>1219</a>     parse_dates=parse_dates,
#    <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=1219'>1220</a>     thousands=thousands,
#    <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=1220'>1221</a>     attrs=attrs,
#    <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=1221'>1222</a>     encoding=encoding,
#    <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=1222'>1223</a>     decimal=decimal,
#    <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=1223'>1224</a>     converters=converters,
#    <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=1224'>1225</a>     na_values=na_values,
#    <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=1225'>1226</a>     keep_default_na=keep_default_na,
#    <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=1226'>1227</a>     displayed_only=displayed_only,
#    <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=1227'>1228</a>     extract_links=extract_links,
#    <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=1228'>1229</a>     dtype_backend=dtype_backend,
#    <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=1229'>1230</a> )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py:1001, in _parse(flavor, io, match, attrs, encoding, displayed_only, extract_links, **kwargs)
#     <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=998'>999</a> else:
#    <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=999'>1000</a>     assert retained is not None  # for mypy
# -> <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=1000'>1001</a>     raise retained
#    <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=1002'>1003</a> ret = []
#    <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=1003'>1004</a> for table in tables:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py:981, in _parse(flavor, io, match, attrs, encoding, displayed_only, extract_links, **kwargs)
#     <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=977'>978</a> p = parser(io, compiled_match, attrs, encoding, displayed_only, extract_links)
#     <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=979'>980</a> try:
# --> <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=980'>981</a>     tables = p.parse_tables()
#     <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=981'>982</a> except ValueError as caught:
#     <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=982'>983</a>     # if `io` is an io-like object, check if it's seekable
#     <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=983'>984</a>     # and try to rewind it before trying the next parser
#     <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=984'>985</a>     if hasattr(io, "seekable") and io.seekable():
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py:257, in _HtmlFrameParser.parse_tables(self)
#     <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=248'>249</a> def parse_tables(self):
#     <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=249'>250</a>     """
#     <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=250'>251</a>     Parse and return all tables from the DOM.
#     <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=251'>252</a>
#    (...)
#     <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=254'>255</a>     list of parsed (header, body, footer) tuples from tables.
#     <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=255'>256</a>     """
# --> <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=256'>257</a>     tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=257'>258</a>     return (self._parse_thead_tbody_tfoot(table) for table in tables)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py:613, in _BeautifulSoupHtml5LibFrameParser._parse_tables(self, doc, match, attrs)
#     <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=609'>610</a> tables = doc.find_all(element_name, attrs=attrs)
#     <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=611'>612</a> if not tables:
# --> <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=612'>613</a>     raise ValueError("No tables found")
#     <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=614'>615</a> result = []
#     <a href='file:///Users/makarwuckert/opt/anaconda3/lib/python3.9/site-packages/pandas/io/html.py?line=615'>616</a> unique_tables = set()
#
# ValueError: No tables found

# %%
len(all_matches)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 len(all_matches)
#
# NameError: name 'all_matches' is not defined

# %%
match_df = pd.concat(all_matches)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 match_df = pd.concat(all_matches)
#
# NameError: name 'pd' is not defined

# %%
match_df.columns = [c.lower() for c in match_df.columns]
match_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 match_df.columns = [c.lower() for c in match_df.columns]
#       2 match_df
#
# NameError: name 'match_df' is not defined

# %%
#match_df.to_csv("matches.csv")
